# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./dataset/test/20.bmp')
img_lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
img_ycbcr = cv2.cvtColor(img, cv2.COLOR_BGR2YCR_CB)
img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
max(img_lab[0, :, :].ravel())
# Out:
# 255

# %% [markdown]
# Make 5 masks:
# 1. Mask for Mouth- Use LAB Channel 2
# 2. Mask for Facial Region-
# 3. Mask for Hair and Eyebrows- Use YCrCB channel 1 dark and channel 3 light
# 4. Mask for Eyes- YUV channel 2 and circularity

# %%
# In LAB Channel 2
# mouth_mask = img_lab[:].copy()

mouth_lower = np.array([100, 170, 150])
mouth_upper = np.array([130, 180, 170])
# mouth_lower = np.array([110, 160, 150])
# mouth_upper = np.array([130, 180, 170])
mouth_mask = cv2.inRange(img_lab, mouth_lower, mouth_upper)

# dilate mouth_mask
kernel = np.ones((3, 3), np.uint8)
# erode mouth_mask
# mouth_mask = cv2.erode(mouth_mask, kernel, iterations=1)
# mouth_mask = cv2.dilate(mouth_mask, kernel, iterations=2)
mouth_mask = cv2.morphologyEx(mouth_mask, cv2.MORPH_CLOSE, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5)))
# cnts, _ = cv2.findContours(mouth_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
# cnt = max(cnts, key=cv2.contourArea)

# Output
# out = np.zeros(mouth_mask.shape, np.uint8)
# cv2.drawContours(out, [cnt], -1, 255, cv2.FILLED)
# mouth_mask = cv2.bitwise_and(mouth_mask, out)
# mouth_mask = cv2.dilate(mouth_mask, kernel, iterations=2)
# mouth_mask[:,:,0] = mouth_range
# mouth_mask[:,:,1] = mouth_range
# mouth_mask[:,:,2] = mouth_range

# connectivity = 8
# numLabels, output_labels = cv2.connectedComponents(mouth_mask, connectivity=connectivity, ltype=cv2.CV_32S)
# print(numLabels)

plt.imshow(mouth_mask, cmap='gray')

# %%
# %matplotlib notebook
plt.imshow(img_hsv)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
face_lower = np.array([5, 60, 180])
face_upper = np.array([12, 200, 250])

kernel = np.ones((3, 3), np.uint8)
face_mask = cv2.inRange(img_hsv, face_lower, face_upper)
face_mask = cv2.dilate(face_mask, kernel, iterations=5)
plt.imshow(face_mask)

# %%
plt.imshow(img_hsv)
plt.show()

# %%
circles = cv2.HoughCircles(img_lab, cv2.HOUGH_GRADIENT, 1, 20, param1=50, param2=30, minRadius=0, maxRadius=0)
circles
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /var/folders/sg/4x_5htrx3y7fm7z77wcz8c_40000gn/T/ipykernel_12503/3142715410.py in <module>
# ----> 1 circles = cv2.HoughCircles(img_lab, cv2.HOUGH_GRADIENT, 1, 20, param1=50, param2=30, minRadius=0, maxRadius=0)
#       2 circles
#
# error: OpenCV(4.5.3) /private/var/folders/24/8k48jl6d249_n_qfxwsl6xvm0000gn/T/pip-req-build-xxsyexfp/opencv/modules/imgproc/src/hough.cpp:2253: error: (-215:Assertion failed) !_image.empty() && _image.type() == CV_8UC1 && (_image.isMat() || _image.isUMat()) in function 'HoughCircles'
